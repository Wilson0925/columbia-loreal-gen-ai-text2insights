# %%
# !pip install google-cloud-aiplatform==1.25.0
# Out:
# Collecting google-cloud-aiplatform==1.25.0
#   Downloading google_cloud_aiplatform-1.25.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform==1.25.0) (2.11.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform==1.25.0) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform==1.25.0) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform==1.25.0) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform==1.25.0) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform==1.25.0) (3.12.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform==1.25.0) (1.10.4)
# Collecting shapely<2.0.0 (from google-cloud-aiplatform==1.25.0)
#   Downloading Shapely-1.8.5.post1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (2.17.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (1.59.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (1.48.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.25.0) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.25.0) (2.6.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.25.0) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform==1.25.0) (0.12.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.25.0) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (2023.7.22)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.25.0) (0.5.0)
# Installing collected packages: shapely, google-cloud-aiplatform
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.2
#     Uninstalling shapely-2.0.2:
#       Successfully uninstalled shapely-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed google-cloud-aiplatform-1.25.0 shapely-1.8.5.post1

# %%
# !pip install vertexai
# Out:
# Collecting vertexai
#   Downloading vertexai-0.0.1-py3-none-any.whl (6.0 kB)
# Installing collected packages: vertexai
# Successfully installed vertexai-0.0.1

# %%
# !pip install sql_metadata
# Out:
# Collecting sql_metadata
#   Downloading sql_metadata-2.10.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: sqlparse<0.5.0,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from sql_metadata) (0.4.4)
# Installing collected packages: sql_metadata
# Successfully installed sql_metadata-2.10.0

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=24df9c5f29a4c1cf584ddf365adf7f46b697a52ee140ea8d0559b11f2dbfa72e
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: sentencepiece, sentence_transformers
# Successfully installed sentence_transformers-2.2.2 sentencepiece-0.1.99

# %%
import pandas as pd


file_path = '/content/drive/MyDrive/loreal/sql_samples.xlsx'

# Read the Excel file into a pandas DataFrame

df_sample = pd.read_excel(file_path, sheet_name='dataset',header=1)
# Display the DataFrame
q_sql=df_sample.iloc[:, 0:2][0:102]


sql_schema=df_sample.iloc[:, 0:2][103:]
sql_schema.columns=['Schema','type']

# %%
import pandas as pd

# Read the text file
with open('/content/drive/MyDrive/loreal/question_match.txt', 'r') as file:
    text = file.read()

# Split text into chunks based on empty lines
chunks = text.strip().split('\n\n')

# Process each chunk and split into components
data = []
for chunk in chunks:
    lines = chunk.split('\n')
    question = lines[0].replace('Question: ', '').strip()
    sql_match = lines[1].replace('SQL Column Match: ', '').strip()
    explanation = lines[2].replace('Explanation: ', '').strip()
    data.append([question, sql_match, explanation])

# Create DataFrame
df = pd.DataFrame(data, columns=['Question', 'SQL Column Match', 'Explanation'])

# Display the DataFrame
df
# Out:
#                                               Question  \
# 0                           What is ACD total revenue?
# 1       What is the total sales for each brand in YTD?
# 2                               What is LRP’s avg ASP?
# 3    When the product LRP Thermal Spring Water star...
# 4    What is the PPM YTD for LRP Thermal Spring Water?
# ..                                                 ...
# 97   What was the total YTD ordered revenue for AZZ...
# 98   Which IT cosmetics product had the highest YTD...
# 99   What was the total YTD ad spend for lancome in...
# 100  What was the total number of clicks on branded...
# 101  What was the ASP for urban decay products in M...
#
#                                       SQL Column Match  \
# 0                     ORDERED_REVENUE and DIV_DIVISION
# 1                        ORDERED_REVENUE and DIV_BRAND
# 2          AVERAGE_ORDERED_REVENUE_PRICE and DIV_BRAND
# 3               SYNDICATED_MONTH and DIV_PRODUCT_TITLE
# 4              YTD_RETAIL_MARGIN and DIV_PRODUCT_TITLE
# ..                                                 ...
# 97   ORDERED_REVENUE, DIV_BRAND, DIV_MASTER_CATEGOR...
# 98   DIV_PRODUCT_TITLE, RETAIL_MARGIN, DIV_BRAND, D...
# 99   SPEND, DIV_BRAND, DIV_MASTER_CATEGORY, SYNDICA...
# 100  NUMBER_CLICKS, DIV_BRAND, DIV_MASTER_CATEGORY,...
# 101  AVERAGE_ORDERED_REVENUE_PRICE, DIV_BRAND, DIV_...
#
#                                            Explanation
# 0    The query sums the ORDERED_REVENUE for the DIV...
# 1    The query sums the ORDERED_REVENUE for each DI...
# 2    The query calculates the average AVERAGE_ORDER...
# 3    The query finds the earliest SYNDICATED_MONTH ...
# 4    The query calculates the average YTD_RETAIL_MA...
# ..                                                 ...
# 97   The query calculates the total year-to-date or...
# 98   The query identifies the IT cosmetics product ...
# 99   The query calculates the total year-to-date ad...
# 100  The query computes the total number of clicks ...
# 101  The query calculates the average selling price...
#
# [102 rows x 3 columns]

# %%
for i,j in zip(df['Question'].values,q_sql['Natural Language Question'].values):
    if i!=j:
      print(i)
      print(j)
# Out:
# What is the total number of units sold for each division?
# What is the total number of units sold for each division?
# What is the total revenue for LOP in Hair?
# What is the total revenue for LOP in Hair?
# Can you tell me the ASP for each brand in the Hair?
# Can you tell me the asp for each brand in the Hair?
# Cheapest product, skin?
# Cheapest product, skin?
# Top 5 brands, units sold, FC?
# Top 5 brands, units sold, FC?
# Highest chargebacks, Facial?
# Highest chargebacks, Facial?
# Highest brand shipping fee?
# Highest brand shipping fee?
# Highest CVR brand?
# Highest CVR brand?
# Most units sold, Makeup, ACD?
# Most units sold, Makeup, ACD?
# Top 5 products, most chargebacks, ACD?
# Top 5 products, most chargebacks, ACD?
# What was the total ad spend for the Hair Color, CPD in 19?
# What was the total ad spend for the Hair Color, CPD in 19?
# What were the top 3 brands with the highest conversion rate in Mkp?
# What were the top 3 brands with the highest conversion rate in Mkp?
# What are the top 5 products with the most glance views in Hair Care for Q1?
# What are the top 5 products with the most glance views in  Hair Care for Q1?
# What was the total number of clicks on branded ads in Mkp?
# What was the total number of clicks on branded ads in  Mkp?
# What was the total number of clicks on branded ads in Make in Q2 2019?
# What was the total number of clicks on branded ads in Make  in Q2 2019?
# What were the top 5 brands with the highest # of units sold for Q3 2019?
# What were the top 5 brands with the highest # of units sold for Q3 2019?
# What were the top 5 products with the most units sold in ACD for skincare ytd?
# What were the top 5 products with the most units sold in ACD for skincare ytd
# Which product had the highest YTD spend on competitive ads in haircare?
# Which product had the highest YTD spend on competitive ads in  haircare?
# Which product had the highest YTD net PPM in hair color for CPD?
# Which product had the highest YTD net PPM in hair color for CPD
# What was the total number of clicks on branded ads in Hair Care in Feb 20?
# What was the total number of clicks on branded ads in Hair Care  in Feb 20?
# Which IT cosmetics product had the highest YTD net PPM in Makeup in Q2 2022?
# Which IT cosmetics product had the highest YTD net PPM in  Makeup  in Q2 2022?

# %%
df['sql']=q_sql['SQL Query']

# %%
df
# Out:
#                                               Question  \
# 0                           What is ACD total revenue?
# 1       What is the total sales for each brand in YTD?
# 2                               What is LRP’s avg ASP?
# 3    When the product LRP Thermal Spring Water star...
# 4    What is the PPM YTD for LRP Thermal Spring Water?
# ..                                                 ...
# 97   What was the total YTD ordered revenue for AZZ...
# 98   Which IT cosmetics product had the highest YTD...
# 99   What was the total YTD ad spend for lancome in...
# 100  What was the total number of clicks on branded...
# 101  What was the ASP for urban decay products in M...
#
#                                       SQL Column Match  \
# 0                     ORDERED_REVENUE and DIV_DIVISION
# 1                        ORDERED_REVENUE and DIV_BRAND
# 2          AVERAGE_ORDERED_REVENUE_PRICE and DIV_BRAND
# 3               SYNDICATED_MONTH and DIV_PRODUCT_TITLE
# 4              YTD_RETAIL_MARGIN and DIV_PRODUCT_TITLE
# ..                                                 ...
# 97   ORDERED_REVENUE, DIV_BRAND, DIV_MASTER_CATEGOR...
# 98   DIV_PRODUCT_TITLE, RETAIL_MARGIN, DIV_BRAND, D...
# 99   SPEND, DIV_BRAND, DIV_MASTER_CATEGORY, SYNDICA...
# 100  NUMBER_CLICKS, DIV_BRAND, DIV_MASTER_CATEGORY,...
# 101  AVERAGE_ORDERED_REVENUE_PRICE, DIV_BRAND, DIV_...
#
#                                            Explanation  \
# 0    The query sums the ORDERED_REVENUE for the DIV...
# 1    The query sums the ORDERED_REVENUE for each DI...
# 2    The query calculates the average AVERAGE_ORDER...
# 3    The query finds the earliest SYNDICATED_MONTH ...
# 4    The query calculates the average YTD_RETAIL_MA...
# ..                                                 ...
# 97   The query calculates the total year-to-date or...
# 98   The query identifies the IT cosmetics product ...
# 99   The query calculates the total year-to-date ad...
# 100  The query computes the total number of clicks ...
# 101  The query calculates the average selling price...
#
#                                                    sql
# 0    SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE...
# 1    SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE...
# 2    SELECT AVG(AVERAGE_ORDERED_REVENUE_PRICE) FROM...
# 3    SELECT MIN(SYNDICATED_MONTH) FROM amer-amzacce...
# 4    SELECT AVG(YTD_RETAIL_MARGIN) FROM amer-amzacc...
# ..                                                 ...
# 97   SELECT SUM(ORDERED_REVENUE) AS TOTAL_ORDERED_R...
# 98   SELECT DIV_PRODUCT_TITLE, MAX(RETAIL_MARGIN) A...
# 99   SELECT SUM(SPEND) AS TOTAL_AD_SPEND FROM amer-...
# 100  SELECT SUM(NUMBER_CLICKS) AS TOTAL_CLICKS FROM...
# 101  SELECT AVG(AVERAGE_ORDERED_REVENUE_PRICE) AS A...
#
# [102 rows x 4 columns]

# %%
import collections
import json
import os
import re
import sqlite3

from transformers import AutoTokenizer
from sql_metadata import Parser
import pandas as pd
import re
from sql_metadata import Parser

def isFloat(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

def isNegativeInt(value):
    try:
        int_val = int(value)
        return int_val < 0
    except ValueError:
        return False

def sql2skeleton(sql_queries, schema_df):
    column_names = schema_df['Schema'].str.lower().tolist()


    skeletons = []
    for sql in sql_queries:
        parsed_sql = Parser(sql)
        new_sql_tokens = []

        for token in parsed_sql.tokens:
            token_value = token.value.lower()
            # mask column names
            if token_value in column_names:
                new_sql_tokens.append("_")
            # mask string values
            elif token.value.startswith("'") and token.value.endswith("'"):
                new_sql_tokens.append("_")
            # mask positive int number
            elif token.value.isdigit():
                new_sql_tokens.append("_")
            # mask negative int number
            elif isNegativeInt(token.value):
                new_sql_tokens.append("_")
            # mask float number
            elif isFloat(token.value):
                new_sql_tokens.append("_")
            else:
                new_sql_tokens.append(token.value.strip())

        sql_skeleton = " ".join(new_sql_tokens)
        # Additional cleanup can be added here if necessary
        skeletons.append(sql_skeleton)

    return skeletons


# Example usage
sql_queries = ["SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND SYNDICATED_YEAR_NAME = 2023"]


skeletons = sql2skeleton(sql_queries, sql_schema)
print(skeletons)

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import euclidean_distances
import numpy as np

def find_similar_questions(target_question, question_list, top_k=5):
    model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2', device="cpu")

    # Encode the target question and all other questions
    target_embedding = model.encode([target_question])
    question_embeddings = model.encode(question_list)

    # Calculate Euclidean distances
    distances = np.squeeze(euclidean_distances(target_embedding, question_embeddings)).tolist()
    distance_indices = list(range(len(question_list)))

    # Pair distances with their indices and sort them
    pairs = sorted(zip(distances, distance_indices), key=lambda x: x[0])

    # Select top K similar questions
    top_k_pairs = pairs[:top_k]
    similar_questions = [question_list[index] for _, index in top_k_pairs]

    return similar_questions

# Example usage
sql_questions = q_sql['Natural Language Question'].tolist()
target_sql_question = q_sql['Natural Language Question'][1]

top_similar_questions = find_similar_questions(target_sql_question, sql_questions, top_k=5)
print(top_similar_questions)

def jaccard_similarity(skeleton1, skeleton2):
    tokens1 = skeleton1.strip().split(" ")
    tokens2 = skeleton2.strip().split(" ")
    total = len(tokens1) + len(tokens2)

    def list_to_dict(tokens):
        token_dict = collections.defaultdict(int)
        for t in tokens:
            token_dict[t] += 1
        return token_dict
    token_dict1 = list_to_dict(tokens1)
    token_dict2 = list_to_dict(tokens2)

    intersection = 0
    for t in token_dict1:
        if t in token_dict2:
            intersection += min(token_dict1[t], token_dict2[t])
    union = (len(tokens1) + len(tokens2)) - intersection
    return float(intersection) / union
# Assuming q_sql is your DataFrame, sql_schema is your schema, and indices is the list of indices of questions
sql_questions = q_sql['Natural Language Question'].tolist()
indices = []

for question in top_similar_questions:
    try:
        index = sql_questions.index(question)
        indices.append(index)
    except ValueError:
        print(f"Question '{question}' not found")
def select_top_question_by_jaccard(q_sql, sql_schema, indices, threshold=0.5):
    skeletons = sql2skeleton(q_sql['sql'], sql_schema)
    selected_skeletons = [skeletons[i] for i in indices]

    top_question_indices = []

    for i, skeleton in enumerate(selected_skeletons[1:], start=1):
        similarity = jaccard_similarity(selected_skeletons[0], skeleton)

        if similarity >= threshold:
            top_question_indices.append(indices[i])

    top_questions = q_sql.iloc[top_question_indices,]
    return top_questions

# Example usage


# Now 'indices' contains the indices of the similar questions
# q_sql['SQL Query'][indices]
top_question_pairs = select_top_question_by_jaccard(df, sql_schema, indices)
top_question_pairs
class QuestionSqlExampleStyle(object):
    """Provide QA pair as examples with a specific format."""

    def get_example_prefix(self):
        return "/* Some SQL examples are provided based on similar problems: */\n"

    def format_example(self, example):
        template_qa = ("/* Answer the following: {} */\n"
                       "/* Given the following column match : */\n"
                       "SQL Column Match: {}\n"
                       "Explanation: {}\n"
                       "A:{}")
        return template_qa.format(example['Question'],
                                  example['SQL Column Match'],
                                  example['Explanation'],
                                  example['sql'])

def format_questions_sql_pairs(df):
    formatter = QuestionSqlExampleStyle()
    formatted_examples = formatter.get_example_prefix()

    for _, row in df.iterrows():
        formatted_examples += formatter.format_example(row) + "\n\n"

    return formatted_examples



formatted_output = format_questions_sql_pairs(top_question_pairs)
print(formatted_output)
def create_table_statement(schema_df, table_name,example):

    # Start the CREATE TABLE statement
    sql = '/* Given the following database schema : */\n'+f"CREATE TABLE {table_name} (\n"

    # Add column definitions
    column_defs = []
    template_question =  "/* Answer the following: {} */"
    prompt_question =template_question.format(example)
    for index, row in schema_df.iterrows():
        column_name = row['Schema']
        data_type = row['type']

        # Append the column definition to the list
        column_defs.append(f"    {column_name} {data_type}")

    # Combine all column definitions and add to the statement
    sql += ",\n".join(column_defs)

    # End the CREATE TABLE statement
    sql += "\n);"+prompt_question + "\nA: SELECT "


    return sql

table_schema=create_table_statement(sql_schema, table_name='amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard',example=target_sql_question)

print(table_schema)
# Out:
# ['SELECT SUM ( _ ) AS _ FROM amer - amzaccelerator - data - us - qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE _ = _ AND _ = _']
# ['What is the total sales for each brand in YTD?', 'Top 5 brands, units sold, FC? ', 'What were the top 5 products with the highest YTD ordered revenue in the Skin Care category in the ACD division?', 'Which product in skinc had the highest ordered revenue ytd?', 'What are the top 3 brands with the largest increase in units sold between 21 and 22 in Cosmetics?']
# /* Some SQL examples are provided based on similar problems: */
# /* Answer the following: Top 5 brands, units sold, FC? */
# /* Given the following column match : */
# SQL Column Match: DIV_BRAND, ORDERED_UNITS, DIV_MASTER_CATEGORY
# Explanation: The query lists the top 5 brands (DIV_BRAND) in the 'FACIAL SKINCARE' category (DIV_MASTER_CATEGORY) based on the total units sold (ORDERED_UNITS) in 2023.
# A:SELECT DIV_BRAND, SUM(ORDERED_UNITS) AS ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FACIAL SKINCARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY ORDERED_UNITS DESC LIMIT 5
#
# /* Answer the following: What were the top 5 products with the highest YTD ordered revenue in the Skin Care category in the ACD division? */
# /* Given the following column match : */
# SQL Column Match: DIV_PRODUCT_TITLE, ORDERED_REVENUE, DIV_MASTER_CATEGORY, DIV_DIVISION
# Explanation: The query lists the top 5 products (DIV_PRODUCT_TITLE) in the 'SKIN CARE' category (DIV_MASTER_CATEGORY) of the 'ACD' division (DIV_DIVISION) based on the highest year-to-date ordered revenue (TOTAL_ORDERED_REVENUE) for 2023.
# A:SELECT DIV_PRODUCT_TITLE, SUM(ORDERED_REVENUE) AS TOTAL_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND DIV_DIVISION = 'ACD' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_ORDERED_REVENUE DESC LIMIT 5
#
# /* Answer the following: Which product in skinc had the highest ordered revenue ytd? */
# /* Given the following column match : */
# SQL Column Match: DIV_PRODUCT_TITLE, YTD_ORDERED_REVENUE, DIV_MASTER_CATEGORY
# Explanation: The query identifies the product (DIV_PRODUCT_TITLE) with the highest year-to-date ordered revenue (HIGHEST_YTD_ORDERED_REVENUE) in the 'SKIN CARE' category (DIV_MASTER_CATEGORY) in 2019.
# A:SELECT DIV_PRODUCT_TITLE, MAX(YTD_ORDERED_REVENUE) AS HIGHEST_YTD_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2019 AND YTD_ORDERED_REVENUE NOT NULL GROUP BY DIV_PRODUCT_TITLE ORDER BY HIGHEST_YTD_ORDERED_REVENUE DESC LIMIT 1
#
#
# /* Given the following database schema : */
# CREATE TABLE amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard (
#     PROD_KEY STRING,
#     DIV_DIVISION STRING,
#     DIV_BRAND STRING,
#     DIV_FRANCHISE STRING,
#     DIV_HERO STRING,
#     DIV_PRODUCT_TITLE STRING,
#     BEGIN_DATE DATE,
#     AVERAGE_ORDERED_REVENUE_PRICE FLOAT,
#     CHANGE_IN_GLANCE_VIEW_PRIOR_PERIOD FLOAT,
#     FAST_TRACK_GLANCE_VIEW FLOAT,
#     FAST_TRACK_GLANCE_VIEW_PRIOR_PERIOD FLOAT,
#     LBB_PRICE FLOAT,
#     OPEN_PURCHASE_ORDER_QUANTITY FLOAT,
#     ORDERED_REVENUE FLOAT,
#     ORDERED_UNITS FLOAT,
#     REP_OOS FLOAT,
#     RETAIL_MARGIN FLOAT,
#     SHIPPED_COGS FLOAT,
#     SHIPPED_REVENUE FLOAT,
#     SHIPPED_UNITS FLOAT,
#     PERCENTAGE_OF_TOTAL_GVS FLOAT,
#     NET_PPM_AMZR FLOAT,
#     SELLABLE_OH_INVENTORY FLOAT,
#     NET_PPU FLOAT,
#     CP FLOAT,
#     WEIGHTED_LBB_ASIN FLOAT,
#     CHANGE_IN_DETAIL_PAGE_VIEW_ASIN FLOAT,
#     WEIGHTED_REP_OOS_ASIN FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     PERCENTAGE_OF_TOTAL_GVS_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     FAST_TRACK_GLANCE_VIEW_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     WOB_ORDERED_REVENUE FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_ASIN FLOAT,
#     WEIGHTED_LBB_FRANCHISE FLOAT,
#     CHANGE_IN_DETAIL_PAGE_VIEW_FRANCHISE FLOAT,
#     WEIGHTED_REP_OOS_FRANCHISE FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_FRANCHISE FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_FRANCHISE_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     DIFF_IN_WEIGHTED_FAST_TRACK_GLANCE_VIEW FLOAT,
#     CHANGE_IN_GV_KPI FLOAT,
#     PERCENTAGE_TRADE_RATE FLOAT,
#     DIV_FUTURE_HERO STRING,
#     DIV_HERO_FAMILY STRING,
#     DIV_HERO_PARENT STRING,
#     DIV_MASTER_CATEGORY STRING,
#     DIV_PROFITERO_CATEGORY STRING,
#     DIV_AXE STRING,
#     DIV_SUB_AXE STRING,
#     DIV_SUB_FAMILY STRING,
#     DIV_SUB_FRANCHISE STRING,
#     NET_PP_AMT FLOAT,
#     NET_MARGIN FLOAT,
#     DIV_CLASS STRING,
#     DIV_PACK_TYPE STRING,
#     PROFITERO_SUB_CATEGORY STRING,
#     HERO_CMO_MAPPING STRING,
#     YTD_LBB_PRICE FLOAT,
#     YTD_ORDERED_REVENUE_LAST_YEAR FLOAT,
#     YTD_ORDERED_REVENUE FLOAT,
#     YTD_ORDERED_UNITS_LAST_YEAR FLOAT,
#     YTD_ORDERED_UNITS FLOAT,
#     YTD_REP_OOS FLOAT,
#     YTD_SHIPPED_COGS FLOAT,
#     YTD_SHIPPED_REVENUE FLOAT,
#     YTD_RETAIL_MARGIN NUMERIC,
#     ORDERED_REVENUE_SAME_PERIOD_LY FLOAT,
#     ORDERED_UNITS_SAME_PERIOD_LY FLOAT,
#     WEEKLY_PROP_OF_ORDERED_REVENUE FLOAT,
#     SNS_WEEKLY_SUBSCRIPTION_REVENUE FLOAT,
#     SNS_WEEKLY_SUBSCRIPTION_UNITS FLOAT,
#     SNS_WEEKLY_SUBSCRIPTIONS FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_ASIN_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     PO_ACCEPTED_QTY INTEGER,
#     PO_QTY_REQUESTED INTEGER,
#     TOTAL_PO_COST NUMERIC,
#     AVAILABLE_INVENTORY INTEGER,
#     YTD_ORDERED_REVENUE_LY_ACTUAL_VALUE NUMERIC,
#     YTD_ORDERED_UNITS_LY_ACTUAL_VALUE FLOAT,
#     ORDERED_REVENUE FLOAT,
#     ORDERED_REVENUE_BRANDED FLOAT,
#     ORDERED_REVENUE_GENERIC FLOAT,
#     ORDERED_REVENUE_COMPETETIVE FLOAT,
#     ORDERED_REVENUE_AUTO FLOAT,
#     ORDERED_REVENUE_NON_BEAUTY FLOAT,
#     ORDERED_REVENUE_UNDEFINED FLOAT,
#     CONVERSION INTEGER,
#     CONVERSION_BRANDED INTEGER,
#     CONVERSION_GENERIC INTEGER,
#     CONVERSION_COMPETETIVE INTEGER,
#     CONVERSION_AUTO INTEGER,
#     CONVERSION_NON_BEAUTY INTEGER,
#     CONVERSION_UNDEFINED INTEGER,
#     SPEND FLOAT,
#     SPEND_BRANDED FLOAT,
#     SPEND_GENERIC FLOAT,
#     SPEND_COMPETETIVE FLOAT,
#     SPEND_AUTO FLOAT,
#     SPEND_NON_BEAUTY FLOAT,
#     SPEND_UNDEFINED FLOAT,
#     NUMBER_CLICKS INTEGER,
#     YTD_TOTAL_ORDERED_REVENUE FLOAT,
#     YTD_TOTAL_ORDERS INTEGER,
#     YTD_TOTAL_AD_SPEND FLOAT,
#     CHARGEBACK FLOAT,
#     DIV_MSRP FLOAT,
#     SHIPPING_FEE FLOAT,
#     DIV_UNIT_COST FLOAT,
#     CHARGEBACK_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     FLAG INTEGER,
#     GLANCE_VIEWS INTEGER,
#     YTD_GLANCE_VIEWS INTEGER,
#     GLANCE_VIEWS_PRIOR_PERIOD INTEGER,
#     GLANCE_VIEWS_SAME_PERIOD_LY INTEGER,
#     CONVERSION_RATE FLOAT,
#     LBB_COUNT_ASIN FLOAT,
#     LBB_COUNT_ASIN_PRIOR_PERIOD FLOAT,
#     REPOOS_COUNT_ASIN FLOAT,
#     REPOOS_COUNT_ASIN_PRIOR_PERIOD FLOAT,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD INTEGER,
#     CHANGE_IN_GLANCE_VIEW_COUNT FLOAT,
#     AVERAGE_ORDERED_REVENUE_PRICE_ASIN_CALCULATED FLOAT,
#     LBB_DOLLAR_LOSS FLOAT,
#     REPOOS_DOLLAR_LOSS FLOAT,
#     FTGV_DOLLAR_LOSS FLOAT,
#     DISPLAY_CLICKS INTEGER,
#     AFFILIATE_CLICKS INTEGER,
#     CONVERSION_RATE_CALC FLOAT,
#     STANDARD_CVR FLOAT,
#     PRODUCT_TYPE_SEARCH STRING,
#     SYNDICATED_YEAR_NAME INTEGER,
#     SYNDICATED_QUARTER_NAME INTEGER,
#     SYNDICATED_MONTH_NAME INTEGER,
#     SYNDICATED_WEEK_NAME INTEGER,
#     SYNDICATED_MONTH DATE,
#     SYNDICATED_MONTH_PREV DATE,
#     SYNDICATED_QUARTER DATE,
#     SYNDICATED_QUARTER_PREV DATE,
#     SYNDICATED_YEAR DATE,
#     SYNDICATED_YEAR_PREV DATE,
#     SYNDICATED_MONTH_NAME_ORIGINAL STRING,
#     SYNDICATED_QUARTER_NAME_ORIGINAL STRING,
#     SYNDICATED_YEAR_NAME_ORIGINAL STRING,
#     SYNDICATED_YEAR_MONTH STRING,
#     SYNDICATED_YEAR_QUARTER STRING,
#     ORDERED_REVENUE_MONTH FLOAT,
#     ORDERED_REVENUE_QUARTER FLOAT,
#     ORDERED_REVENUE_YEAR FLOAT,
#     ORDERED_UNITS_MONTH FLOAT,
#     ORDERED_UNITS_QUARTER FLOAT,
#     ORDERED_UNITS_YEAR FLOAT,
#     GLANCE_VIEWS_MONTH INTEGER,
#     GLANCE_VIEWS_QUARTER INTEGER,
#     GLANCE_VIEWS_YEAR INTEGER,
#     CHARGEBACK_MONTH FLOAT,
#     CHARGEBACK_QUARTER FLOAT,
#     CHARGEBACK_YEAR FLOAT,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_MONTH INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_QUARTER INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_YEAR INTEGER,
#     CONVERSION_RATE_MONTH FLOAT,
#     CONVERSION_RATE_QUARTER FLOAT,
#     CONVERSION_RATE_YEAR FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_MONTH FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_QUARTER FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_YEAR FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_MONTH FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_QUARTER FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_YEAR FLOAT,
#     GLANCE_VIEWS_PRIOR_PERIOD_MONTH INTEGER,
#     GLANCE_VIEWS_PRIOR_PERIOD_QUARTER INTEGER,
#     GLANCE_VIEWS_PRIOR_PERIOD_YEAR INTEGER,
#     CHARGEBACK_PRIOR_PERIOD_MONTH FLOAT,
#     CHARGEBACK_PRIOR_PERIOD_QUARTER FLOAT,
#     CHARGEBACK_PRIOR_PERIOD_YEAR FLOAT,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD_MONTH INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD_QUARTER INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD_YEAR INTEGER,
#     CONVERSION_RATE_PRIOR_PERIOD_MONTH FLOAT,
#     CONVERSION_RATE_PRIOR_PERIOD_QUARTER FLOAT,
#     CONVERSION_RATE_PRIOR_PERIOD_YEAR FLOAT,
#     GLANCE_VIEWS_SAME_PERIOD_LY_MONTH INTEGER,
#     GLANCE_VIEWS_SAME_PERIOD_LY_QUARTER INTEGER,
#     ORDERED_REVENUE_SAME_PERIOD_LY_MONTH FLOAT,
#     ORDERED_REVENUE_SAME_PERIOD_LY_QUARTER FLOAT,
#     ORDERED_UNITS_SAME_PERIOD_LY_MONTH FLOAT,
#     ORDERED_UNITS_SAME_PERIOD_LY_QUARTER FLOAT
# );/* Answer the following: What is the total sales for each brand in YTD? */
# A: SELECT

# %%
q_sql.iloc[[42, 96, 75],]
# Out:
#                             Natural Language Question  \
# 42                     Top 5 brands, units sold, FC?
# 96  What were the top 5 products with the highest ...
# 75  Which product in skinc had the highest ordered...
#
#                                             SQL Query
# 42  SELECT DIV_BRAND, SUM(ORDERED_UNITS) AS ORDERE...
# 96  SELECT DIV_PRODUCT_TITLE, SUM(ORDERED_REVENUE)...
# 75  SELECT DIV_PRODUCT_TITLE, MAX(YTD_ORDERED_REVE...

# %%
def combined_function(df, sql_schema,  target_question_index, top_k=5, threshold=0.3):
    # Generate SQL skeletons
    sql_questions = df['Question'].tolist()

    target_sql_question=df['Question'][target_question_index]
    top_similar_questions = find_similar_questions(target_sql_question, sql_questions, top_k)
    indices = []
    for question in top_similar_questions:
            index = sql_questions.index(question)
            indices.append(index)
    top_question_pairs = select_top_question_by_jaccard(df, sql_schema, indices)
    # Format the question-SQL pairs
    formatted_output = format_questions_sql_pairs(top_question_pairs)
    table_schema=create_table_statement(sql_schema, table_name='amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard',example=target_sql_question)
    final_prompt=formatted_output+table_schema


    return final_prompt

# Example usage
# Assuming q_sql is your DataFrame of questions and answers, and sql_schema is your schema DataFrame
formatted_output = combined_function(df, sql_schema, target_question_index=2)
print(formatted_output)
# Out:
# /* Some SQL examples are provided based on similar problems: */
# /* Answer the following: How many skus does LRP have? */
# /* Given the following column match : */
# SQL Column Match: DIV_PRODUCT_TITLE and DIV_BRAND
# Explanation: The query counts the distinct DIV_PRODUCT_TITLE for the brand 'LA ROCHE-POSAY' (LRP).
# A:SELECT COUNT (1) FROM (SELECT DISTINCT(DIV_PRODUCT_TITLE) FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_BRAND = 'LA ROCHE-POSAY')
#
# /* Answer the following: Highest asp, FR? */
# /* Given the following column match : */
# SQL Column Match: DIV_PRODUCT_TITLE, AVERAGE_ORDERED_REVENUE_PRICE, DIV_MASTER_CATEGORY
# Explanation: The query identifies the product (DIV_PRODUCT_TITLE) with the highest average selling price (AVERAGE_ORDERED_REVENUE_PRICE) in the 'FRAGRANCE' category (DIV_MASTER_CATEGORY) for 2023.
# A:SELECT DIV_PRODUCT_TITLE, AVG(AVERAGE_ORDERED_REVENUE_PRICE) AS AVG_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FRAGRANCE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_PRODUCT_TITLE ORDER BY AVG_PRICE DESC LIMIT 1
#
# /* Answer the following: What is the PPM YTD for LRP Thermal Spring Water? */
# /* Given the following column match : */
# SQL Column Match: YTD_RETAIL_MARGIN and DIV_PRODUCT_TITLE
# Explanation: The query calculates the average YTD_RETAIL_MARGIN for the product 'La Roche-Posay Thermal Spring Water, 10.1 Fl oz.' for the year 2023.
# A:SELECT AVG(YTD_RETAIL_MARGIN) FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_PRODUCT_TITLE = 'La Roche-Posay Thermal Spring Water, 10.1 Fl oz.' AND SYNDICATED_YEAR_NAME = 2023
#
# /* Given the following database schema : */
# CREATE TABLE amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard (
#     PROD_KEY STRING,
#     DIV_DIVISION STRING,
#     DIV_BRAND STRING,
#     DIV_FRANCHISE STRING,
#     DIV_HERO STRING,
#     DIV_PRODUCT_TITLE STRING,
#     BEGIN_DATE DATE,
#     AVERAGE_ORDERED_REVENUE_PRICE FLOAT,
#     CHANGE_IN_GLANCE_VIEW_PRIOR_PERIOD FLOAT,
#     FAST_TRACK_GLANCE_VIEW FLOAT,
#     FAST_TRACK_GLANCE_VIEW_PRIOR_PERIOD FLOAT,
#     LBB_PRICE FLOAT,
#     OPEN_PURCHASE_ORDER_QUANTITY FLOAT,
#     ORDERED_REVENUE FLOAT,
#     ORDERED_UNITS FLOAT,
#     REP_OOS FLOAT,
#     RETAIL_MARGIN FLOAT,
#     SHIPPED_COGS FLOAT,
#     SHIPPED_REVENUE FLOAT,
#     SHIPPED_UNITS FLOAT,
#     PERCENTAGE_OF_TOTAL_GVS FLOAT,
#     NET_PPM_AMZR FLOAT,
#     SELLABLE_OH_INVENTORY FLOAT,
#     NET_PPU FLOAT,
#     CP FLOAT,
#     WEIGHTED_LBB_ASIN FLOAT,
#     CHANGE_IN_DETAIL_PAGE_VIEW_ASIN FLOAT,
#     WEIGHTED_REP_OOS_ASIN FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     PERCENTAGE_OF_TOTAL_GVS_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     FAST_TRACK_GLANCE_VIEW_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     WOB_ORDERED_REVENUE FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_ASIN FLOAT,
#     WEIGHTED_LBB_FRANCHISE FLOAT,
#     CHANGE_IN_DETAIL_PAGE_VIEW_FRANCHISE FLOAT,
#     WEIGHTED_REP_OOS_FRANCHISE FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_FRANCHISE FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_FRANCHISE_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     DIFF_IN_WEIGHTED_FAST_TRACK_GLANCE_VIEW FLOAT,
#     CHANGE_IN_GV_KPI FLOAT,
#     PERCENTAGE_TRADE_RATE FLOAT,
#     DIV_FUTURE_HERO STRING,
#     DIV_HERO_FAMILY STRING,
#     DIV_HERO_PARENT STRING,
#     DIV_MASTER_CATEGORY STRING,
#     DIV_PROFITERO_CATEGORY STRING,
#     DIV_AXE STRING,
#     DIV_SUB_AXE STRING,
#     DIV_SUB_FAMILY STRING,
#     DIV_SUB_FRANCHISE STRING,
#     NET_PP_AMT FLOAT,
#     NET_MARGIN FLOAT,
#     DIV_CLASS STRING,
#     DIV_PACK_TYPE STRING,
#     PROFITERO_SUB_CATEGORY STRING,
#     HERO_CMO_MAPPING STRING,
#     YTD_LBB_PRICE FLOAT,
#     YTD_ORDERED_REVENUE_LAST_YEAR FLOAT,
#     YTD_ORDERED_REVENUE FLOAT,
#     YTD_ORDERED_UNITS_LAST_YEAR FLOAT,
#     YTD_ORDERED_UNITS FLOAT,
#     YTD_REP_OOS FLOAT,
#     YTD_SHIPPED_COGS FLOAT,
#     YTD_SHIPPED_REVENUE FLOAT,
#     YTD_RETAIL_MARGIN NUMERIC,
#     ORDERED_REVENUE_SAME_PERIOD_LY FLOAT,
#     ORDERED_UNITS_SAME_PERIOD_LY FLOAT,
#     WEEKLY_PROP_OF_ORDERED_REVENUE FLOAT,
#     SNS_WEEKLY_SUBSCRIPTION_REVENUE FLOAT,
#     SNS_WEEKLY_SUBSCRIPTION_UNITS FLOAT,
#     SNS_WEEKLY_SUBSCRIPTIONS FLOAT,
#     WEIGHTED_FAST_TRACK_GLANCE_VIEW_ASIN_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     PO_ACCEPTED_QTY INTEGER,
#     PO_QTY_REQUESTED INTEGER,
#     TOTAL_PO_COST NUMERIC,
#     AVAILABLE_INVENTORY INTEGER,
#     YTD_ORDERED_REVENUE_LY_ACTUAL_VALUE NUMERIC,
#     YTD_ORDERED_UNITS_LY_ACTUAL_VALUE FLOAT,
#     ORDERED_REVENUE FLOAT,
#     ORDERED_REVENUE_BRANDED FLOAT,
#     ORDERED_REVENUE_GENERIC FLOAT,
#     ORDERED_REVENUE_COMPETETIVE FLOAT,
#     ORDERED_REVENUE_AUTO FLOAT,
#     ORDERED_REVENUE_NON_BEAUTY FLOAT,
#     ORDERED_REVENUE_UNDEFINED FLOAT,
#     CONVERSION INTEGER,
#     CONVERSION_BRANDED INTEGER,
#     CONVERSION_GENERIC INTEGER,
#     CONVERSION_COMPETETIVE INTEGER,
#     CONVERSION_AUTO INTEGER,
#     CONVERSION_NON_BEAUTY INTEGER,
#     CONVERSION_UNDEFINED INTEGER,
#     SPEND FLOAT,
#     SPEND_BRANDED FLOAT,
#     SPEND_GENERIC FLOAT,
#     SPEND_COMPETETIVE FLOAT,
#     SPEND_AUTO FLOAT,
#     SPEND_NON_BEAUTY FLOAT,
#     SPEND_UNDEFINED FLOAT,
#     NUMBER_CLICKS INTEGER,
#     YTD_TOTAL_ORDERED_REVENUE FLOAT,
#     YTD_TOTAL_ORDERS INTEGER,
#     YTD_TOTAL_AD_SPEND FLOAT,
#     CHARGEBACK FLOAT,
#     DIV_MSRP FLOAT,
#     SHIPPING_FEE FLOAT,
#     DIV_UNIT_COST FLOAT,
#     CHARGEBACK_PRIOR_PERIOD_ACTUAL_VAL FLOAT,
#     FLAG INTEGER,
#     GLANCE_VIEWS INTEGER,
#     YTD_GLANCE_VIEWS INTEGER,
#     GLANCE_VIEWS_PRIOR_PERIOD INTEGER,
#     GLANCE_VIEWS_SAME_PERIOD_LY INTEGER,
#     CONVERSION_RATE FLOAT,
#     LBB_COUNT_ASIN FLOAT,
#     LBB_COUNT_ASIN_PRIOR_PERIOD FLOAT,
#     REPOOS_COUNT_ASIN FLOAT,
#     REPOOS_COUNT_ASIN_PRIOR_PERIOD FLOAT,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD INTEGER,
#     CHANGE_IN_GLANCE_VIEW_COUNT FLOAT,
#     AVERAGE_ORDERED_REVENUE_PRICE_ASIN_CALCULATED FLOAT,
#     LBB_DOLLAR_LOSS FLOAT,
#     REPOOS_DOLLAR_LOSS FLOAT,
#     FTGV_DOLLAR_LOSS FLOAT,
#     DISPLAY_CLICKS INTEGER,
#     AFFILIATE_CLICKS INTEGER,
#     CONVERSION_RATE_CALC FLOAT,
#     STANDARD_CVR FLOAT,
#     PRODUCT_TYPE_SEARCH STRING,
#     SYNDICATED_YEAR_NAME INTEGER,
#     SYNDICATED_QUARTER_NAME INTEGER,
#     SYNDICATED_MONTH_NAME INTEGER,
#     SYNDICATED_WEEK_NAME INTEGER,
#     SYNDICATED_MONTH DATE,
#     SYNDICATED_MONTH_PREV DATE,
#     SYNDICATED_QUARTER DATE,
#     SYNDICATED_QUARTER_PREV DATE,
#     SYNDICATED_YEAR DATE,
#     SYNDICATED_YEAR_PREV DATE,
#     SYNDICATED_MONTH_NAME_ORIGINAL STRING,
#     SYNDICATED_QUARTER_NAME_ORIGINAL STRING,
#     SYNDICATED_YEAR_NAME_ORIGINAL STRING,
#     SYNDICATED_YEAR_MONTH STRING,
#     SYNDICATED_YEAR_QUARTER STRING,
#     ORDERED_REVENUE_MONTH FLOAT,
#     ORDERED_REVENUE_QUARTER FLOAT,
#     ORDERED_REVENUE_YEAR FLOAT,
#     ORDERED_UNITS_MONTH FLOAT,
#     ORDERED_UNITS_QUARTER FLOAT,
#     ORDERED_UNITS_YEAR FLOAT,
#     GLANCE_VIEWS_MONTH INTEGER,
#     GLANCE_VIEWS_QUARTER INTEGER,
#     GLANCE_VIEWS_YEAR INTEGER,
#     CHARGEBACK_MONTH FLOAT,
#     CHARGEBACK_QUARTER FLOAT,
#     CHARGEBACK_YEAR FLOAT,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_MONTH INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_QUARTER INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_YEAR INTEGER,
#     CONVERSION_RATE_MONTH FLOAT,
#     CONVERSION_RATE_QUARTER FLOAT,
#     CONVERSION_RATE_YEAR FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_MONTH FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_QUARTER FLOAT,
#     ORDERED_REVENUE_PRIOR_PERIOD_YEAR FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_MONTH FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_QUARTER FLOAT,
#     ORDERED_UNITS_PRIOR_PERIOD_YEAR FLOAT,
#     GLANCE_VIEWS_PRIOR_PERIOD_MONTH INTEGER,
#     GLANCE_VIEWS_PRIOR_PERIOD_QUARTER INTEGER,
#     GLANCE_VIEWS_PRIOR_PERIOD_YEAR INTEGER,
#     CHARGEBACK_PRIOR_PERIOD_MONTH FLOAT,
#     CHARGEBACK_PRIOR_PERIOD_QUARTER FLOAT,
#     CHARGEBACK_PRIOR_PERIOD_YEAR FLOAT,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD_MONTH INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD_QUARTER INTEGER,
#     FAST_TRACK_GLANCE_VIEW_COUNT_ASIN_PRIOR_PERIOD_YEAR INTEGER,
#     CONVERSION_RATE_PRIOR_PERIOD_MONTH FLOAT,
#     CONVERSION_RATE_PRIOR_PERIOD_QUARTER FLOAT,
#     CONVERSION_RATE_PRIOR_PERIOD_YEAR FLOAT,
#     GLANCE_VIEWS_SAME_PERIOD_LY_MONTH INTEGER,
#     GLANCE_VIEWS_SAME_PERIOD_LY_QUARTER INTEGER,
#     ORDERED_REVENUE_SAME_PERIOD_LY_MONTH FLOAT,
#     ORDERED_REVENUE_SAME_PERIOD_LY_QUARTER FLOAT,
#     ORDERED_UNITS_SAME_PERIOD_LY_MONTH FLOAT,
#     ORDERED_UNITS_SAME_PERIOD_LY_QUARTER FLOAT
# );/* Answer the following: What is LRP’s avg ASP? */
# A: SELECT

# %% [markdown]
# how to get a dictionary match between columne name and column in question

# %%
from google.colab import auth as google_auth
google_auth.authenticate_user()
import vertexai
from vertexai.preview.language_models import TextGenerationModel
PROJECT_ID='cv2023fall'
def predict_large_language_model_sample(
    project_id: str,
    model_name: str,
    temperature: float,
    max_decode_steps: int,
    top_p: float,
    top_k: int,
    content: str,
    location: str = "us-central1",
    tuned_model_name: str = "",
    ) :
    """Predict using a Large Language Model."""
    vertexai.init(project=project_id, location=location)
    model = TextGenerationModel.from_pretrained(model_name)
    if tuned_model_name:
      model = model.get_tuned_model(tuned_model_name)
    response = model.predict(
        content,
        temperature=temperature,
        max_output_tokens=max_decode_steps,
        top_k=top_k,
        top_p=top_p,)
    # print(f"Response from Model: {response.text}")
    return response.text
test_out=predict_large_language_model_sample(PROJECT_ID, "text-bison@001", 0.2, 256, 0.8, 40, '''Give me ten interview questions for the role of program manager''', "us-central1")

# %%
df
# Out:
#                                               Question  \
# 0                           What is ACD total revenue?
# 1       What is the total sales for each brand in YTD?
# 2                               What is LRP’s avg ASP?
# 3    When the product LRP Thermal Spring Water star...
# 4    What is the PPM YTD for LRP Thermal Spring Water?
# ..                                                 ...
# 96   What was the total YTD ordered revenue for AZZ...
# 97   Which IT cosmetics product had the highest YTD...
# 98   What was the total YTD ad spend for lancome in...
# 99   What was the total number of clicks on branded...
# 100  What was the ASP for urban decay products in M...
#
#                                       SQL Column Match  \
# 0                     ORDERED_REVENUE and DIV_DIVISION
# 1                        ORDERED_REVENUE and DIV_BRAND
# 2          AVERAGE_ORDERED_REVENUE_PRICE and DIV_BRAND
# 3               SYNDICATED_MONTH and DIV_PRODUCT_TITLE
# 4              YTD_RETAIL_MARGIN and DIV_PRODUCT_TITLE
# ..                                                 ...
# 96   ORDERED_REVENUE, DIV_BRAND, DIV_MASTER_CATEGOR...
# 97   DIV_PRODUCT_TITLE, RETAIL_MARGIN, DIV_BRAND, D...
# 98   SPEND, DIV_BRAND, DIV_MASTER_CATEGORY, SYNDICA...
# 99   NUMBER_CLICKS, DIV_BRAND, DIV_MASTER_CATEGORY,...
# 100  AVERAGE_ORDERED_REVENUE_PRICE, DIV_BRAND, DIV_...
#
#                                            Explanation  \
# 0    The query sums the ORDERED_REVENUE for the DIV...
# 1    The query sums the ORDERED_REVENUE for each DI...
# 2    The query calculates the average AVERAGE_ORDER...
# 3    The query finds the earliest SYNDICATED_MONTH ...
# 4    The query calculates the average YTD_RETAIL_MA...
# ..                                                 ...
# 96   The query calculates the total year-to-date or...
# 97   The query identifies the IT cosmetics product ...
# 98   The query calculates the total year-to-date ad...
# 99   The query computes the total number of clicks ...
# 100  The query calculates the average selling price...
#
#                                                    sql
# 0    SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE...
# 1    SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE...
# 2    SELECT AVG(AVERAGE_ORDERED_REVENUE_PRICE) FROM...
# 3    SELECT MIN(SYNDICATED_MONTH) FROM amer-amzacce...
# 4    SELECT AVG(YTD_RETAIL_MARGIN) FROM amer-amzacc...
# ..                                                 ...
# 96   SELECT DIV_PRODUCT_TITLE, SUM(ORDERED_REVENUE)...
# 97   SELECT SUM(ORDERED_REVENUE) AS TOTAL_ORDERED_R...
# 98   SELECT DIV_PRODUCT_TITLE, MAX(RETAIL_MARGIN) A...
# 99   SELECT SUM(SPEND) AS TOTAL_AD_SPEND FROM amer-...
# 100  SELECT SUM(NUMBER_CLICKS) AS TOTAL_CLICKS FROM...
#
# [101 rows x 4 columns]

# %%
prediction=[]
for i in range(q_sql.shape[0]):
    formatted_output=combined_function(df, sql_schema, target_question_index=i)

# Call the function with the new prompt
    output=predict_large_language_model_sample(PROJECT_ID, "text-bison@001", 0.2, 500, 0.8, 40, formatted_output, "us-central1")

    output='SELECT '+ re.sub(' +', ' ', output.replace("\n", " ")).strip()

    print(f'{1+i},{output}')
    prediction.append(output)
# Out:
# 1,SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND SYNDICATED_YEAR_NAME = 2023
# 2,SELECT div_brand, sum(ordered_revenue) as total_sales FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE div_division = 'ACD' AND div_master_category = 'SKIN CARE' AND syndicated_year_name = 2023 GROUP BY div_brand ORDER BY total_sales DESC
# 3,SELECT AVG(AVERAGE_ORDERED_REVENUE_PRICE) AS AVG_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_BRAND = 'LA ROCHE-POSAY'
# 4,SELECT MIN(SYNDICATED_MONTH) FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_PRODUCT_TITLE = 'La Roche-Posay Thermal Spring Water, 10.1 Fl oz.'
# 5,SELECT PPM_YTD FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_PRODUCT_TITLE = 'La Roche-Posay Thermal Spring Water, 10.1 Fl oz.'
# 6,SELECT DIV_BRAND, SUM(ORDERED_UNITS) AS ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY ORDERED_UNITS DESC LIMIT 10
# 7,SELECT PROD_KEY, DIV_PRODUCT_TITLE, ORDERED_REVENUE, ORDERED_UNITS, REP_OOS, RETAIL_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' ORDER BY ORDERED_REVENUE DESC LIMIT 3
# 8,SELECT COUNT(DISTINCT PROD_KEY) FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_BRAND = 'LA ROCHE-POSAY'
# 9,SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND SYNDICATED_YEAR_NAME = 2023
# 10,SELECT PROD_KEY, DIV_DIVISION, DIV_BRAND, DIV_FRANCHISE, DIV_HERO, DIV_PRODUCT_TITLE, SUM(ORDERED_REVENUE) AS ORDERED_REVENUE, SUM(ORDERED_UNITS) AS ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY ORDERED_REVENUE DESC LIMIT 10
# 11,SELECT div_division, SUM(ordered_revenue) AS total_revenue FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard GROUP BY div_division
# 12,SELECT PROD_KEY, AVERAGE_ORDERED_REVENUE_PRICE AS ASP FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'MAKEUP' AND SYNDICATED_YEAR_NAME = 2023 ORDER BY ASP DESC LIMIT 3
# 13,SELECT div_division, SUM(ordered_units) AS total_units_sold FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard GROUP BY div_division
# 14,SELECT DIV_BRAND, AVG(YTD_RETAIL_MARGIN) AS AVG_RETAIL_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' GROUP BY DIV_BRAND
# 15,SELECT PROD_KEY, MAX(RETAIL_MARGIN) AS MAX_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FRAGRANCES' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY MAX_MARGIN DESC LIMIT 1
# 16,SELECT SUM(ORDERED_REVENUE) AS TOTAL_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND DIV_DIVISION = 'LOP' AND SYNDICATED_YEAR_NAME = 2023 AND SPEND NOT NULL
# 17,SELECT DIV_PRODUCT_TITLE, (SUM(CASE WHEN SYNDICATED_YEAR_NAME = 2023 THEN ORDERED_REVENUE ELSE 0 END) - SUM(CASE WHEN SYNDICATED_YEAR_NAME = 2022 THEN ORDERED_REVENUE ELSE 0 END)) AS REVENUE_GROWTH, ((SUM(CASE WHEN SYNDICATED_YEAR_NAME = 2023 THEN ORDERED_REVENUE ELSE 0 END) - SUM(CASE WHEN SYNDICATED_YEAR_NAME = 2022 THEN ORDERED_REVENUE ELSE 0 END)) / SUM(CASE WHEN SYNDICATED_YEAR_NAME = 2022 THEN ORDERED_REVENUE ELSE 0 END)) * 100 AS GROWTH_PERCENT FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKINC' AND SYNDICATED_YEAR_NAME IN (2022, 2023) GROUP BY DIV_PRODUCT_TITLE ORDER BY REVENUE_GROWTH DESC LIMIT 5
# 18,SELECT t1.DIV_BRAND, (SUM(CASE WHEN t1.SYNDICATED_YEAR_NAME = 2022 THEN t1.ORDERED_UNITS ELSE 0 END) - SUM(CASE WHEN t1.SYNDICATED_YEAR_NAME = 2021 THEN t1.ORDERED_UNITS ELSE 0 END)) AS UNITS_SOLD_GROWTH FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard AS t1 WHERE t1.DIV_MASTER_CATEGORY = 'COSMETICS' AND t1.SYNDICATED_YEAR_NAME IN (2021, 2022) GROUP BY t1.DIV_BRAND ORDER BY UNITS_SOLD_GROWTH DESC LIMIT 3
# 19,SELECT PROD_KEY, DIV_PRODUCT_TITLE, AVERAGE_ORDERED_REVENUE_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' ORDER BY AVERAGE_ORDERED_REVENUE_PRICE DESC LIMIT 5
# 20,SELECT t1.DIV_BRAND, t1.AVG_RETAIL_MARGIN FROM (SELECT DIV_BRAND, AVG(RETAIL_MARGIN) AS AVG_RETAIL_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard GROUP BY DIV_BRAND) AS t1 ORDER BY AVG_RETAIL_MARGIN DESC LIMIT 1
# 21,SELECT t1.DIV_PRODUCT_TITLE, t1.REVENUE_GROWTH FROM ( SELECT DIV_PRODUCT_TITLE, (SUM(CASE WHEN SYNDICATED_YEAR_NAME = 2023 THEN ORDERED_REVENUE ELSE 0 END) - SUM(CASE WHEN SYNDICATED_YEAR_NAME = 2022 THEN ORDERED_REVENUE ELSE 0 END)) AS REVENUE_GROWTH FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_YEAR_NAME IN (2022, 2023) GROUP BY DIV_PRODUCT_TITLE ORDER BY REVENUE_GROWTH DESC ) t1 WHERE t1.REVENUE_GROWTH >= 10 ORDER BY t1.REVENUE_GROWTH DESC LIMIT 3
# 22,SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FACIAL SKINCARE' AND SYNDICATED_YEAR_NAME = 2023
# 23,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(ORDERED_UNITS) AS TOTAL_ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_ORDERED_UNITS DESC LIMIT 1
# 24,SELECT DIV_BRAND, AVERAGE_ORDERED_REVENUE_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR' GROUP BY DIV_BRAND
# 25,SELECT DIV_BRAND, SUM(ORDERED_UNITS) AS TOTAL_ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'MAKEUP' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY TOTAL_ORDERED_UNITS DESC LIMIT 10
# 26,SELECT PROD_KEY, SUM(ORDERED_UNITS) AS ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2022 GROUP BY PROD_KEY
# 27,SELECT DIV_BRAND, SUM(ORDERED_REVENUE) AS ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY ORDERED_REVENUE DESC LIMIT 3
# 28,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(ORDERED_UNITS) AS ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR COLOR' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_PRODUCT_TITLE ORDER BY ORDERED_UNITS DESC LIMIT 1
# 29,SELECT PROD_KEY, MAX(RETAIL_MARGIN) AS MAX_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'MAKEUP' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY MAX_MARGIN DESC LIMIT 1
# 30,SELECT SUM(ORDERED_UNITS) AS TOTAL_UNITS_SOLD FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FACIAL SKINCARE'
# 31,SELECT PROD_KEY, MIN(ORDERED_REVENUE) AS MIN_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'COLOR COSMETICS' GROUP BY PROD_KEY ORDER BY MIN_REVENUE ASC LIMIT 1
# 32,SELECT PROD_KEY, DIV_PRODUCT_TITLE, MAX(DIV_MSRP) AS HIGHEST_MSRP FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'NAIL CARE' GROUP BY DIV_PRODUCT_TITLE ORDER BY HIGHEST_MSRP DESC LIMIT 1
# 33,SELECT PROD_KEY, DIV_DIVISION, DIV_PRODUCT_TITLE, AVERAGE_ORDERED_REVENUE_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' ORDER BY AVERAGE_ORDERED_REVENUE_PRICE DESC LIMIT 5
# 34,SELECT PROD_KEY, SUM(ORDERED_UNITS) AS TOTAL_ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'LPD' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY TOTAL_ORDERED_UNITS DESC LIMIT 1
# 35,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(ORDERED_REVENUE) AS ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'COSMETICS' GROUP BY PROD_KEY, DIV_PRODUCT_TITLE ORDER BY ORDERED_REVENUE DESC LIMIT 3
# 36,SELECT PROD_KEY, MAX(YTD_RETAIL_MARGIN) AS MAX_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'CC' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY MAX_MARGIN DESC LIMIT 1
# 37,SELECT PROD_KEY, SUM(ORDERED_REVENUE) AS TOTAL_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'HC' ORDER BY TOTAL_REVENUE LIMIT 5 OFFSET 5
# 38,SELECT AVG(AVERAGE_ORDERED_REVENUE_PRICE) AS AVERAGE_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN' AND AVERAGE_ORDERED_REVENUE_PRICE NOT NULL
# 39,SELECT PROD_KEY, DIV_PRODUCT_TITLE, ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'STYLING' AND ORDERED_UNITS IS NOT NULL ORDER BY ORDERED_UNITS DESC LIMIT 1
# 40,SELECT div_product_title, min(retail_margin) as min_margin FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE div_master_category = 'COLOR COSMETICS' AND retail_margin is not null GROUP BY div_product_title ORDER BY min_margin asc limit 1
# 41,SELECT SUM(ORDERED_REVENUE) AS ORDERED_REVENUE, SUM(CPD) AS CPD FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard
# 42,SELECT PROD_KEY, MIN(LBB_PRICE) AS MIN_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023 AND LBB_PRICE NOT NULL GROUP BY PROD_KEY ORDER BY MIN_PRICE ASC LIMIT 1
# 43,SELECT DIV_BRAND, SUM(ORDERED_UNITS) AS UNITS, SUM(FAST_TRACK_GLANCE_VIEW) AS FC FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY UNITS DESC LIMIT 5
# 44,SELECT PROD_KEY, MAX(AVERAGE_ORDERED_REVENUE_PRICE) AS HIGHEST_AVG_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'FRAGRANCE' GROUP BY PROD_KEY ORDER BY HIGHEST_AVG_PRICE DESC LIMIT 1
# 45,SELECT PROD_KEY, MAX(NET_PPM_AMZR) AS HIGHEST_PPM FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY HIGHEST_PPM DESC LIMIT 3
# 46,SELECT PROD_KEY, DIV_PRODUCT_TITLE, MAX(GLANCE_VIEWS) AS TOTAL_GV FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' GROUP BY PROD_KEY, DIV_PRODUCT_TITLE ORDER BY TOTAL_GV DESC LIMIT 1
# 47,SELECT PROD_KEY, DIV_PRODUCT_TITLE, STANDARD_CVR, DIV_FRANCHISE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_FRANCHISE = 'FR' ORDER BY STANDARD_CVR DESC LIMIT 5
# 48,SELECT PROD_KEY, SUM(REP_OOS) AS TOTAL_OOS_DAYS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR COLOR' AND SYNDICATED_YEAR_NAME = 2023 AND REP_OOS NOT NULL GROUP BY PROD_KEY ORDER BY TOTAL_OOS_DAYS DESC LIMIT 1
# 49,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(CHARGEBACK) AS TOTAL_CHARGEBACKS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FACIAL SKINCARE' AND SYNDICATED_YEAR_NAME = 2023 AND CHARGEBACK NOT NULL GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_CHARGEBACKS DESC LIMIT 1
# 50,SELECT PROD_KEY, MAX(PO_QTY_REQUESTED) AS MOST_PO_REQUESTED_QTY FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY MOST_PO_REQUESTED_QTY DESC LIMIT 1
# 51,SELECT SUM(SPEND) AS TOTAL_AD_SPEND FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'COLOR COSMETICS'
# 52,SELECT PROD_KEY, MAX(CONVERSION_RATE) AS MAX_CVR FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'COLOR COSMETICS' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY MAX_CVR DESC LIMIT 1
# 53,SELECT PROD_KEY, DIV_PRODUCT_TITLE, MAX(CHARGEBACK) AS TOTAL_CHARGEBACKS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'MAKEUP' AND SYNDICATED_YEAR_NAME = 2023 AND CHARGEBACK NOT NULL GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_CHARGEBACKS DESC LIMIT 1
# 54,SELECT PROD_KEY, SUM(GLANCE_VIEWS) AS TOTAL_GV FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'COSMETICS' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY TOTAL_GV DESC LIMIT 5
# 55,SELECT DIV_BRAND, MIN(NET_PPM_AMZR) AS LOWEST_PPM FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' GROUP BY DIV_BRAND ORDER BY LOWEST_PPM ASC
# 56,SELECT DIV_BRAND, MAX(SHIPPING_FEE) AS MAX_SHIPPING_FEE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard GROUP BY DIV_BRAND ORDER BY MAX_SHIPPING_FEE DESC LIMIT 1
# 57,SELECT DIV_BRAND, SUM(GLANCE_VIEWS) AS TOTAL_GV FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY TOTAL_GV DESC LIMIT 3
# 58,SELECT DIV_BRAND, AVG(CONVERSION_RATE) AS AVG_CVR FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY AVG_CVR DESC LIMIT 1
# 59,SELECT PROD_KEY, SUM(REP_OOS) AS TOTAL_OOS_DAYS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FSK INC' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY TOTAL_OOS_DAYS DESC LIMIT 1
# 60,SELECT DIV_BRAND, MIN(RETAIL_MARGIN) AS MIN_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_BRAND ORDER BY MIN_MARGIN ASC LIMIT 1
# 61,SELECT PROD_KEY, SUM(ORDERED_UNITS) AS TOTAL_ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND DIV_AXE = 'MAKEUP' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY TOTAL_ORDERED_UNITS DESC LIMIT 1
# 62,SELECT PROD_KEY, DIV_PRODUCT_TITLE, DIV_MSRP FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND DIV_MSRP IS NOT NULL ORDER BY DIV_MSRP DESC LIMIT 1
# 63,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(CHARGEBACK) AS TOTAL_CHARGEBACK FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_CHARGEBACK DESC LIMIT 5
# 64,SELECT PROD_KEY, MAX(RETAIL_MARGIN) AS HIGHEST_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY HIGHEST_MARGIN DESC LIMIT 1
# 65,SELECT SUM(SPEND) AS TOTAL_AD_SPEND FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR COLOR' AND SYNDICATED_YEAR_NAME = 2019 AND DIV_DIVISION = 'CPD'
# 66,SELECT PROD_KEY, MAX(REP_OOS) AS MAX_OOS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_YEAR_NAME = 2021 GROUP BY PROD_KEY ORDER BY MAX_OOS DESC LIMIT 1
# 67,SELECT t1.DIV_BRAND, t1.CONVERSION_RATE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard t1 WHERE t1.SYNDICATED_YEAR_NAME = 2023 AND t1.DIV_DIVISION = 'MKP' ORDER BY t1.CONVERSION_RATE DESC LIMIT 3
# 68,SELECT PROD_KEY, DIV_PRODUCT_TITLE, DIV_MSRP FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'FR' ORDER BY DIV_MSRP LIMIT 1
# 69,SELECT MAX(SPEND_COMPETETIVE) AS HIGHEST_SPEND_COMPETETIVE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'LPD' AND SYNDICATED_YEAR_NAME = 2023
# 70,SELECT PROD_KEY, MAX(AVERAGE_ORDERED_REVENUE_PRICE) AS HIGHEST_AVG_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' GROUP BY PROD_KEY ORDER BY HIGHEST_AVG_PRICE DESC LIMIT 1
# 71,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(GLANCE_VIEWS) AS TOTAL_GV FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_YEAR_NAME = 2023 AND SYNDICATED_QUARTER_NAME = 1 AND GLANCE_VIEWS NOT NULL GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_GV DESC LIMIT 5
# 72,SELECT DIV_BRAND, SUM(ORDERED_REVENUE) AS ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'COSMETICS' GROUP BY DIV_BRAND ORDER BY ORDERED_REVENUE DESC LIMIT 1
# 73,SELECT SUM(NUMBER_CLICKS) AS TOTAL_CLICKS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'MKP' AND DIV_BRAND = 'MKP' AND SYNDICATED_YEAR_NAME = 2023 AND SYNDICATED_QUARTER_NAME = 4 AND NUMBER_CLICKS NOT NULL
# 74,SELECT DIV_BRAND, MAX(SELLABLE_OH_INVENTORY) AS MAX_SELLABLE_OH_INVENTORY FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_MONTH_NAME = 5 AND SYNDICATED_YEAR_NAME = 2022 GROUP BY DIV_BRAND
# 75,SELECT MAX(SPEND_AUTO) AS HIGHEST_AUTO_AD_SPEND FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'COLOUR COSMETICS' AND SPEND_AUTO IS NOT NULL
# 76,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(ORDERED_REVENUE) AS TOTAL_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_ORDERED_REVENUE DESC LIMIT 1
# 77,SELECT DIV_PRODUCT_TITLE, MAX(NET_MARGIN) AS MAX_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'MAKEUP' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_PRODUCT_TITLE ORDER BY MAX_MARGIN DESC LIMIT 3
# 78,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(GLANCE_VIEWS) AS TOTAL_GV FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_YEAR_NAME = 2021 AND SYNDICATED_QUARTER_NAME = 1 GROUP BY DIV_PRODUCT_TITLE ORDER BY TOTAL_GV DESC LIMIT 3
# 79,SELECT DIV_PRODUCT_TITLE, MAX(YTD_RETAIL_MARGIN) AS MAX_MARGIN FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FAC SKINC' AND YTD_RETAIL_MARGIN IS NOT NULL GROUP BY DIV_PRODUCT_TITLE ORDER BY MAX_MARGIN DESC LIMIT 1
# 80,SELECT SUM(NUMBER_CLICKS) AS TOTAL_CLICKS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'MAKEUP' AND SYNDICATED_YEAR_NAME = 2019 AND SYNDICATED_QUARTER_NAME = 2
# 81,SELECT PROD_KEY FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_PRODUCT_TITLE = 'Garnier SkinActive Micellar Cleansing Water'
# 82,SELECT DISTINCT DIV_BRAND FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard
# 83,SELECT t1.DIV_BRAND, SUM(t1.YTD_ORDERED_REVENUE) AS YTD_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard AS t1 WHERE t1.DIV_MASTER_CATEGORY = 'ACD' GROUP BY t1.DIV_BRAND ORDER BY YTD_ORDERED_REVENUE DESC LIMIT 1
# 84,SELECT t1.DIV_BRAND, SUM(t1.ORDERED_UNITS) AS ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard AS t1 WHERE t1.SYNDICATED_QUARTER_NAME = 201903 GROUP BY t1.DIV_BRAND ORDER BY ORDERED_UNITS DESC LIMIT 5
# 85,SELECT PROD_KEY, MIN(NET_PPM_AMZR) AS LOWEST_YTD_NET_PPM FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE SYNDICATED_YEAR_NAME = 2020 AND SYNDICATED_QUARTER_NAME = 4 GROUP BY PROD_KEY
# 86,SELECT SUM(SPEND) AS TOTAL_AD_SPEND FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023
# 87,SELECT PROD_KEY, AVERAGE_ORDERED_REVENUE_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'FACIAL' AND SYNDICATED_YEAR_NAME = 2021 AND SYNDICATED_QUARTER_NAME = 3 AND AVERAGE_ORDERED_REVENUE_PRICE IS NOT NULL ORDER BY AVERAGE_ORDERED_REVENUE_PRICE DESC LIMIT 1
# 88,SELECT SUM(ORDERED_UNITS) AS ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_BRAND = 'KERASTASE' AND SYNDICATED_QUARTER_NAME = 4 AND SYNDICATED_YEAR_NAME = 2022
# 89,SELECT PROD_KEY, CONVERSION_RATE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'NYX' AND SYNDICATED_QUARTER_NAME = 'Q1 19' AND CONVERSION_RATE IS NOT NULL ORDER BY CONVERSION_RATE DESC LIMIT 1
# 90,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(ORDERED_UNITS) AS TOTAL_ORDERED_UNITS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY, DIV_PRODUCT_TITLE ORDER BY TOTAL_ORDERED_UNITS DESC LIMIT 5
# 91,SELECT PROD_KEY, MAX(SPEND_COMPETETIVE) AS MAX_SPEND FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_YEAR_NAME = 2023 AND SPEND_COMPETETIVE IS NOT NULL GROUP BY PROD_KEY ORDER BY MAX_SPEND DESC LIMIT 1
# 92,SELECT SUM(ORDERED_REVENUE) AS TOTAL_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_BRAND = 'MAYBELLINE' AND SYNDICATED_MONTH_NAME = 1 AND SYNDICATED_YEAR_NAME = 2019
# 93,SELECT ORDERED_REVENUE_SAME_PERIOD_LY - ORDERED_REVENUE AS YOY_CHANGE_IN_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_HERO = 'Azzaro'
# 94,SELECT PROD_KEY, DIV_DIVISION, DIV_BRAND, DIV_FRANCHISE, DIV_HERO, DIV_PRODUCT_TITLE, BEGIN_DATE, AVERAGE_ORDERED_REVENUE_PRICE, CHANGE_IN_GLANCE_VIEW_PRIOR_PERIOD, FAST_TRACK_GLANCE_VIEW, FAST_TRACK_GLANCE_VIEW_PRIOR_PERIOD, LBB_PRICE, OPEN_PURCHASE_ORDER_QUANTITY, ORDERED_REVENUE, ORDERED_UNITS, REP_OOS, RETAIL_MARGIN, SHIPPED_COGS, SHIPPED_REVENUE, SHIPPED_UNITS, PERCENTAGE_OF_TOTAL_GVS, NET_PPM_AMZR, SELLABLE_OH_INVENTORY, NET_PPU, CP, WEIGHTED_LBB_ASIN, CHANGE_IN_DETAIL_PAGE_VIEW_ASIN, WEIGHTED_REP_OOS_ASIN, ORDERED_REVENUE_PRIOR_PERIOD_ACTUAL_VAL, ORDERED_UNITS_PRIOR_PERIOD_ACTUAL_VAL, PERCENTAGE_OF_TOTAL_GVS_PRIOR_PERIOD_ACTUAL_VAL, FAST_TRACK_GLANCE_VIEW_PRIOR_PERIOD_ACTUAL_VAL, WOB_ORDERED_REVENUE, WEIGHTED_FAST_TRACK_GLANCE_VIEW_ASIN, WEIGHTED_LBB_FRANCHISE, CHANGE_IN_DETAIL_PAGE_VIEW_FRANCHISE, WEIGHTED_REP_OOS_FRANCHISE, WEIGHTED_FAST_TRACK_GLANCE_VIEW_FRANCHISE, WEIGHTED_FAST_TRACK_GLANCE_VIEW_FRANCHISE_PRIOR_PERIOD_ACTUAL_VAL, DIFF_IN_WEIGHTED_FAST_TRACK_GLANCE_VIEW, CHANGE_IN_GV_KPI, PERCENTAGE_TRADE_RATE, DIV_
# 95,SELECT PROD_KEY, MAX(NET_PPM_AMZR) AS HIGHEST_NET_PPM FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR COLOR' AND DIV_DIVISION = 'CPD' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY PROD_KEY ORDER BY HIGHEST_NET_PPM DESC LIMIT 1
# 96,SELECT SUM(NUMBER_CLICKS) AS TOTAL_CLICKS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_MASTER_CATEGORY = 'HAIR CARE' AND SYNDICATED_MONTH_NAME = 2 AND SYNDICATED_YEAR_NAME = 2020 AND NUMBER_CLICKS NOT NULL
# 97,SELECT PROD_KEY, DIV_PRODUCT_TITLE, SUM(ORDERED_REVENUE) AS YTD_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND DIV_MASTER_CATEGORY = 'SKIN CARE' AND SYNDICATED_YEAR_NAME = 2023 GROUP BY DIV_PRODUCT_TITLE ORDER BY YTD_ORDERED_REVENUE DESC LIMIT 5
# 98,SELECT SUM(ORDERED_REVENUE) AS TOTAL_ORDERED_REVENUE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'FR' AND DIV_BRAND = 'AZZARO' AND SYNDICATED_QUARTER_NAME = 1 AND SYNDICATED_YEAR_NAME = 2019
# 99,SELECT PROD_KEY, DIV_PRODUCT_TITLE, DIV_AXE, DIV_BRAND, NET_PPM_AMZR, YTD_NET_PPM_AMZR FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_AXE = 'MAKEUP' AND DIV_BRAND = 'IT COSMETICS' AND SYNDICATED_QUARTER_NAME = 202202 AND YTD_NET_PPM_AMZR IS NOT NULL ORDER BY YTD_NET_PPM_AMZR DESC LIMIT 1
# 100,SELECT SUM(SPEND) AS TOTAL_AD_SPEND FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'ACD' AND DIV_MASTER_CATEGORY = 'SKIN CARE' AND DIV_BRAND = 'LANCOME' AND SYNDICATED_YEAR_NAME = 2023 AND SYNDICATED_QUARTER_NAME = 1 AND SPEND NOT NULL
# 101,SELECT SUM(NUMBER_CLICKS) AS TOTAL_CLICKS FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_BRAND = 'RALPH LAUREN' AND DIV_MASTER_CATEGORY = 'FRAGRANCE' AND SYNDICATED_YEAR_NAME = 2019 AND SYNDICATED_QUARTER_NAME = 4 AND NUMBER_CLICKS NOT NULL
# 102,SELECT AVERAGE_ORDERED_REVENUE_PRICE FROM amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard WHERE DIV_DIVISION = 'LPD' AND DIV_BRAND = 'URBAN DECAY' AND DIV_AXE = 'MAKEUP' AND SYNDICATED_MONTH_NAME = 'September' AND SYNDICATED_YEAR_NAME = 2021

# %%
len(prediction)
# Out:
# 102

# %%
def calculate_exact_match(generated_sql, ground_truth_sql):
    # Normalize the SQL queries (optional, but recommended)
    normalized_generated_sql = generated_sql.strip().lower()
    normalized_ground_truth_sql = ground_truth_sql.strip().lower()

    # Compare for exact match
    return normalized_generated_sql == normalized_ground_truth_sql

# Example usage

exact_match_score=0
for i in range(102):
    exact_match = calculate_exact_match(prediction[i],q_sql['SQL Query'].values[i] )
    exact_match_score +=exact_match

#with column
exact_match_score
# Out:
# 5

# %%
with open("/content/drive/MyDrive/loreal/palm_prediction_1.txt", "w") as file:
    for item in prediction:
        file.write(item + "\n")

# %%
qm_path = "/content/drive/MyDrive/loreal/wenxi_zhang/data/palm_prediction_1.txt"
with open(qm_path, 'r') as file:
    # Read lines into a list, stripping the newline character from each line
    lines = [line.strip() for line in file]
ground_tru=[]
palm=[]
for i in q_sql['SQL Query']:
  gt=i.replace("amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard", "df")
  ground_tru.append(gt)

for i in lines:
  gt=i.replace("amer-amzaccelerator-data-us-qa.amztech_bqdset_us_qa_view.view_gold_commercial_dashboard", "df")
  palm.append(gt)
import sqlite3
import pandas as pd
import pyarrow.parquet as pq
parquet_file = '/content/drive/My Drive/loreal/anonymized_amz_data_dashboard.parquet'
file_path = parquet_file
table = pq.read_table(file_path)

def convert_dbdate(data):
    return data.astype(str)

converted_columns = {field.name: convert_dbdate(table[field.name]) if 'dbdate' in str(field.type) else table[field.name] for field in table.schema}

df = pd.DataFrame(converted_columns)


df.shape
conn = sqlite3.connect('my_database.db')
# Write the data to a SQLite table
df.to_sql('df', conn, if_exists='replace', index=False)
result=[]
for te in ground_tru:
  try:
    cursor = conn.cursor()
    cursor.execute(te)
    result_from_ground_truth = cursor.fetchall()
    cursor.close()
  except Exception as e:
        result_from_ground_truth = str(e)
  result.append(result_from_ground_truth)
palm_result=[]
for q in palm:
    try:
      cursor = conn.cursor()
      cursor.execute(q)
      result_from_p = cursor.fetchall()
      cursor.close()
    except Exception as e:
      result_from_p = str(e)
    palm_result.append(result_from_p)
successful_executions=0
for i,j in zip(result,palm_result):
  if i and j:
    if i == j:
        successful_executions += 1

# %%
successful_executions
# Out:
# 29

# %%
successful_executions/102
# Out:
# 0.28431372549019607
